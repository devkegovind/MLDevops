# %%
import pandas as pd

# %%
df = pd.read_csv("D:\Downloads\wine+quality\winequality-red.csv", sep=";")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0            7.4              0.70         0.00             1.9      0.076  \
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 0                 11.0                  34.0   0.9978  3.51       0.56  \
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df)

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 1534            6.6              0.56         0.14             2.4      0.064  \
# 609             6.3              0.36         0.19             3.2      0.075
# 959             8.0              0.59         0.05             2.0      0.089
# 411             9.1              0.45         0.35             2.4      0.080
# 419             6.8              0.77         0.00             1.8      0.066
# ...             ...               ...          ...             ...        ...
# 1536            6.1              0.53         0.08             1.9      0.077
# 241            12.0              0.38         0.56             2.1      0.093
# 964             8.5              0.47         0.27             1.9      0.058
# 1541            7.4              0.25         0.29             2.2      0.054
# 90              7.9              0.52         0.26             1.9      0.079
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 1534                 13.0                  29.0  0.99397  3.42       0.62  \
# 609                  15.0                  39.0  0.99560  3.56       0.52
# 959                  12.0                  32.0  0.99735  3.36       0.61
# 411                  23.0                  78.0  0.99870  3.38       0.62
# 419                  34.0                  52.0  0.99760  3.62       0.68
# ...                   ...                   ...      ...   ...        ...
# 1536                 24.0                  45.0  0.99528  3.60       0.68
# 241                   6.0                  24.0  0.99925  3.14       0.71
# 964                  18.0                  38.0  0.99518  3.16       0.85
# 1541                 19.0                  49.0  0.99666  3.40       0.76
# 90                   42.0                 140.0  0.99640  3.23       0.54
#
#       alcohol  quality
# 1534     11.7        7
# 609      12.7        6
# 959      10.0        5
# 411       9.5        5
# 419       9.9        5
# ...       ...      ...
# 1536     10.3        6
# 241      10.9        6
# 964      11.1        6
# 1541     10.9        7
# 90        9.5        5
#
# [1199 rows x 12 columns]

# %%
test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 737             8.2             0.590         0.00             2.5      0.093  \
# 1121            6.6             0.500         0.00             1.8      0.062
# 367            10.4             0.575         0.61             2.6      0.076
# 723             7.1             0.310         0.30             2.2      0.053
# 1153            9.6             0.420         0.35             2.1      0.083
# ...             ...               ...          ...             ...        ...
# 673             8.2             0.730         0.21             1.7      0.074
# 707             7.4             0.490         0.19             3.0      0.077
# 87              7.7             0.490         0.26             1.9      0.062
# 1301            6.7             0.860         0.07             2.0      0.100
# 940             9.6             0.330         0.52             2.2      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 737                  19.0                  58.0  1.00020  3.50       0.65  \
# 1121                 21.0                  28.0  0.99352  3.44       0.55
# 367                  11.0                  24.0  1.00000  3.16       0.69
# 723                  36.0                 127.0  0.99650  2.94       1.62
# 1153                 17.0                  38.0  0.99622  3.23       0.66
# ...                   ...                   ...      ...   ...        ...
# 673                   5.0                  13.0  0.99680  3.20       0.52
# 707                  16.0                  37.0  0.99660  3.37       0.51
# 87                    9.0                  31.0  0.99660  3.39       0.64
# 1301                 20.0                  57.0  0.99598  3.60       0.74
# 940                  13.0                  25.0  0.99509  3.36       0.76
#
#       alcohol  quality
# 737       9.3        6
# 1121     12.3        6
# 367       9.0        5
# 723       9.5        5
# 1153     11.1        6
# ...       ...      ...
# 673       9.5        5
# 707      10.5        5
# 87        9.6        5
# 1301     11.7        6
# 940      12.4        7
#
# [400 rows x 12 columns]

# %%
from sklearn.metrics import roc_auc_score

# %%
X_train = train.drop('quality', axis = 1)
X_test = test.drop('quality', axis = 1)

y_train = train[['quality']]
y_test = test[['quality']]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# C:\Users\Neeta Devke\AppData\Local\Temp\ipykernel_3572\2538021705.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# RandomForestClassifier()

# %%
pred = rf.predict(X_test)

# %%
roc_auc_score(y_test, pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 roc_auc_score(y_test, pred)
#
# File d:\FSDS\venv\Lib\site-packages\sklearn\metrics\_ranking.py:565, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     558         raise ValueError(
#     559             "Partial AUC computation not available in "
#     560             "multiclass setting, 'max_fpr' must be"
#     561             " set to `None`, received `max_fpr={0}` "
#     562             "instead".format(max_fpr)
#     563         )
#     564     if multi_class == "raise":
# --> 565         raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     566     return _multiclass_roc_auc_score(
#     567         y_true, y_score, labels, multi_class, average, sample_weight
#     568     )
#     569 elif y_type == "binary":
#
# ValueError: multi_class must be in ('ovo', 'ovr')

# %%
pred1 = rf.predict_proba(X_test)

# %%
roc_auc_score(y_test, pred1, multi_class='ovr')
# Out:
# 0.8507439497605911
